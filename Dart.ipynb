# %%
import OpenDartReader
import pandas as pd
import numpy as np

# %%
import dart_fss as dart

# %%
corp_list = dart.get_corp_list()
# Out:
# Output()
# Output()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6004/2255128578.py in <module>
# ----> 1 corp_list = dart.get_corp_list()
#
# ~\anaconda3\lib\site-packages\dart_fss\corp\corp_list.py in get_corp_list()
#      16         회사 리스트
#      17     """
# ---> 18     return CorpList()
#      19
#      20
#
# ~\anaconda3\lib\site-packages\dart_fss\utils\singleton.py in __call__(cls, *args, **kwargs)
#       6     def __call__(cls, *args, **kwargs):
#       7         if cls not in cls._instances:
# ----> 8             cls._instances[cls] = super(Singleton, cls).__call__(*args, **kwargs)
#       9         return cls._instances[cls]
#
# ~\anaconda3\lib\site-packages\dart_fss\corp\corp_list.py in __init__(self, profile)
#      67         self._profile = profile
#      68
# ---> 69         self.load(profile=self._profile)
#      70
#      71     def load(self, profile=False):
#
# ~\anaconda3\lib\site-packages\dart_fss\corp\corp_list.py in load(self, profile)
#      78         """
#      79         if self._corps is None:
# ---> 80             self._load(profile=profile)
#      81
#      82     def _load(self, profile=False):
#
# ~\anaconda3\lib\site-packages\dart_fss\corp\corp_list.py in _load(self, profile)
#     101         sectors = set()
#     102
# --> 103         self._corps = [Corp(**x, profile=profile) for x in get_corp_code()]
#     104         for idx, x in enumerate(self._corps):
#     105             self._corp_codes[x.corp_code] = idx
#
# ~\anaconda3\lib\site-packages\dart_fss\api\filings\corp_code.py in get_corp_code()
#      20
#      21         # Set API KEY
# ---> 22         api_key = get_api_key()
#      23         payload = {'crtfc_key': api_key}
#      24
#
# ~\anaconda3\lib\site-packages\dart_fss\auth\auth.py in get_api_key()
#      31         DART_API_KEY
#      32     """
# ---> 33     return DartAuth().api_key
#      34
#      35
#
# ~\anaconda3\lib\site-packages\dart_fss\auth\auth.py in api_key(self)
#      73         """ str: Dart 인증키 """
#      74         if self.__api_key is None:
# ---> 75             raise ValueError('Unauthorized')
#      76         return self.__api_key
#      77
#
# ValueError: Unauthorized

# %%
# Open DART API KEY 설정
api_key = '42a0d56f8478f24dffa336a5ed159b5f51c689f8'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()

# 삼성전자 검색
samsung = corp_list.find_by_corp_name('삼성전자', exactly=True)[0]

# 2012년부터 연간 연결재무제표 불러오기
fs = samsung.extract_fs(bgn_de='20120101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )
fs.save()
# Out:
# Output()
# Output()
# Output()
# Annual reports:   0%|          | 0/10 [00:00<?, ?report/s]
# 'D:\\Project_1\\fsdata\\00126380_annual.xlsx'

# %%
dart2 = OpenDartReader(api_key)

# %%
df = dart1.finstate('삼성전자', 2018)

# %%
dart1.finstate_xml('20190401004781', save_as='삼성전자_2018_사업보고서_XBRL.zip')
# Out:
# True

# %%
corp_list[10]
# Out:
# [00430201]엠와이오피이차유동화전문유한회사

# %%
# Open DART API KEY 설정
api_key = '42a0d56f8478f24dffa336a5ed159b5f51c689f8'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()


name = '245620'
company = corp_list.find_by_corp_code(name, exactly=True)[0]


fs = company.extract_fs(bgn_de='20100101')

# 재무제표 검색 결과를 엑셀파일로 저장 ( 기본저장위치: 실행폴더/fsdata )

filename = f'{name}.xlsx'
path = ''
fs.save(filename=filename)
# Out:
# Annual reports:   0%|          | 0/3 [00:00<?, ?report/s]
# 'D:\\Project_1\\fsdata\\245620.xlsx'

# %%
corp_list.find_by_corp_name(name, exactly=True)[0]
# Out:
# [00760971]크래프톤

# %%
company.load()
# Out:
# {'corp_code': '00760971',
#  'corp_name': '주식회사 크래프톤',
#  'stock_code': '259960',
#  'modify_date': '20210930',
#  'sector': '소프트웨어 개발 및 공급업',
#  'product': '<배틀그라운드> 등 게임 소프트웨어',
#  'corp_cls': 'Y',
#  'corp_name_eng': 'KRAFTON, Inc.',
#  'stock_name': '크래프톤',
#  'ceo_nm': '김창한',
#  'jurir_no': '1101113645772',
#  'bizr_no': '2208745316',
#  'adres': '서울특별시 강남구 테헤란로 231',
#  'hm_url': 'www.krafton.com',
#  'ir_url': '',
#  'phn_no': '02-6250-0807',
#  'fax_no': '',
#  'induty_code': '5821',
#  'est_dt': '20070326',
#  'acc_mt': '12'}

# %%
pd.read_csv('stocks.csv', encoding='euckr')['한글 종목약명'].isna().sum()
# Out:
# 0

# %%
pd.read_csv('stocks.csv', encoding='euckr').iloc[:871]
# Out:
#              표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0    KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1    KR7131100000  131100     (주)스카이이앤엠   스카이이앤엠
# 2    KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 3    KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 4    KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# ..            ...     ...           ...      ...
# 866  KR7032280000  032280            삼일       삼일
# 867  KR7002290005  002290        삼일기업공사   삼일기업공사
# 868  KR7004440004  004440     삼일씨엔에스보통주   삼일씨엔에스
# 869  KR7000520007  000520       삼일제약보통주     삼일제약
# 870  KR7009770009  009770      삼정펄프 보통주     삼정펄프
#
#                               영문 종목명         상장일    시장구분 증권구분          소속부  \
# 0    Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부
# 1                  SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)
# 2              POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부
# 3               AJ Networks Co.,Ltd.  2015/08/21   KOSPI   주권          NaN
# 4                  AK Holdings, Inc.  1999/08/11   KOSPI   주권          NaN
# ..                               ...         ...     ...  ...          ...
# 866                            SamIl  1997/03/15  KOSDAQ   주권        중견기업부
# 867       SAMIL ENTERPRISE CO., LTD.  1992/11/30  KOSDAQ   주권        중견기업부
# 868                        SAMIL C&S  2016/03/30   KOSPI   주권          NaN
# 869              SamilPharmaceutical  1985/05/29   KOSPI   주권          NaN
# 870           SAM JUNG PULP CO,.LTD.  2006/10/17   KOSPI   주권          NaN
#
#     주식종류   액면가     상장주식수
# 0    보통주   500   8312766
# 1    보통주   500  11642629
# 2    보통주   500  41642703
# 3    보통주  1000  46822295
# 4    보통주  5000  13247561
# ..   ...   ...       ...
# 866  보통주  1000  16213590
# 867  보통주   500  12400000
# 868  보통주  1000  12731947
# 869  보통주   500  13537283
# 870  보통주  5000   2499971
#
# [871 rows x 12 columns]

# %%
pd.read_csv('stocks.csv', encoding='euckr')[871:1742]
# Out:
#               표준코드    단축코드   한글 종목명 한글 종목약명                       영문 종목명  \
# 871   KR7037460003  037460     삼지전자    삼지전자  SAMJI ELECTRONICS CO., LTD.
# 872   KR7032750002  032750       삼진      삼진                       Samjin
# 873   KR7054090006  054090    삼진엘앤디   삼진엘앤디   SAMJIN LND COMPANY LIMITED
# 874   KR7005500004  005500  삼진제약보통주    삼진제약         SamjinPharmaceutical
# 875   KR7000250001  000250    삼천당제약   삼천당제약  SAM CHUN DANG PHARM CO. LTD
# ...            ...     ...      ...     ...                          ...
# 1737  KR7091120006  091120      이엠텍     이엠텍           EM-Tech. CO., LTD.
# 1738  KR7232530006  232530      이엠티     이엠티         Energy Material Tech
# 1739  KR7102460003  102460  이연제약보통주    이연제약         REYON PHARMACEUTICAL
# 1740  KR7039030002  039030   이오테크닉스  이오테크닉스        EO Technics Co., Ltd.
# 1741  KR7294090006  294090    이오플로우   이오플로우             EOFlow Co., Ltd.
#
#              상장일    시장구분 증권구분      소속부 주식종류   액면가     상장주식수
# 871   1999/12/16  KOSDAQ   주권    우량기업부  보통주   500  16318522
# 872   1997/07/14  KOSDAQ   주권    우량기업부  보통주   500   6000000
# 873   2004/02/06  KOSDAQ   주권    중견기업부  보통주   500  24959232
# 874   1988/06/18   KOSPI   주권      NaN  보통주  1000  13900000
# 875   2000/10/04  KOSDAQ   주권    우량기업부  보통주   500  22768041
# ...          ...     ...  ...      ...  ...   ...       ...
# 1737  2007/05/02  KOSDAQ   주권    우량기업부  보통주   500  15887936
# 1738  2015/12/30   KONEX   주권    일반기업부  보통주   500  14969643
# 1739  2010/06/10   KOSPI   주권      NaN  보통주   500  17998577
# 1740  2000/08/24  KOSDAQ   주권    우량기업부  보통주   500  12319550
# 1741  2020/09/14  KOSDAQ   주권  기술성장기업부  보통주   100  29491064
#
# [871 rows x 12 columns]

# %%
pd.read_csv('stocks.csv', encoding='euckr')[1742:]
# Out:
#               표준코드    단축코드            한글 종목명  한글 종목약명  \
# 1742  KR7245620000  245620         이원다이애그노믹스     EDGC
# 1743  KR7088290002  088290             이원컴포텍    이원컴포텍
# 1744  KR7084680008  084680            이월드보통주      이월드
# 1745  KR7181340001  181340             이즈미디어    이즈미디어
# 1746  KR7037370004  037370                이지       EG
# ...            ...     ...               ...      ...
# 2609  KR7000542001  000547  흥국화재해상보험2우선주(신형)  흥국화재2우B
# 2610  KR7000540005  000540       흥국화재해상보험보통주     흥국화재
# 2611  KR7003280005  003280           흥아해운보통주     흥아해운
# 2612  KR7037440005  037440        희림종합건축사사무소       희림
# 2613  KR7238490007  238490                힘스       힘스
#
#                                        영문 종목명         상장일    시장구분 증권구분  \
# 1742  Eone Diagnomics Genome Center Co., Ltd.  2018/06/26  KOSDAQ   주권
# 1743                 EWON COMFORTECH CO., LTD  2009/12/01  KOSDAQ   주권
# 1744                                  E-WORLD  2005/07/26   KOSPI   주권
# 1745                         isMedia Co., Ltd  2017/07/26  KOSDAQ   주권
# 1746                           EG CORPORATION  2000/01/11  KOSDAQ   주권
# ...                                       ...         ...     ...  ...
# 2609              HeungkukFire&MarineIns(2PB)  1999/08/09   KOSPI   주권
# 2610             HeungkukFire&MarineInsurance  1974/12/05   KOSPI   주권
# 2611                           HeungaShipping  1976/06/29   KOSPI   주권
# 2612             Heerim Architects & Planners  2000/02/03  KOSDAQ   주권
# 2613                           HIMS CO., LTD.  2017/07/20  KOSDAQ   주권
#
#           소속부   주식종류   액면가      상장주식수
# 1742  기술성장기업부    보통주   100   83694922
# 1743    중견기업부    보통주   500   22636305
# 1744      NaN    보통주  1000  141806193
# 1745    벤처기업부    보통주   500    7120100
# 1746    중견기업부    보통주  1000    8287477
# ...       ...    ...   ...        ...
# 2609      NaN  신형우선주  5000     153600
# 2610      NaN    보통주  5000   64242645
# 2611      NaN    보통주   500  240424899
# 2612    중견기업부    보통주   500   13922475
# 2613    우량기업부    보통주   500   11312236
#
# [872 rows x 12 columns]

# %%
pd.read_csv('stocks.csv', encoding='euckr')['한글 종목명'].iloc[df[df.str.contains('우선주')].index]
# Out:
# 8                BYC1우선주
# 10                CJ1우선주
# 11            CJ4우선주(전환)
# 13             CJ씨푸드1우선주
# 20             DB하이텍1우선주
#               ...
# 2539       현대자동차2우선주(신형)
# 2540       현대자동차3우선주(신형)
# 2558            호텔신라1우선주
# 2608        흥국화재해상보험1우선주
# 2609    흥국화재해상보험2우선주(신형)
# Name: 한글 종목명, Length: 123, dtype: object

# %%
df = pd.read_csv('stocks.csv', encoding='euckr')

# %%
df['한글 종목명'] == '삼성 전자'
# Out:
# Empty DataFrame
# Columns: [표준코드, 단축코드, 한글 종목명, 한글 종목약명, 영문 종목명, 상장일, 시장구분, 증권구분, 소속부, 주식종류, 액면가, 상장주식수]
# Index: []

# %%
corp_list.find_by_stock_code('098120')
# Out:
# [00568188]마이크로컨텍솔

# %%
df[df.단축코드 == '098120']
# Out:
#            표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0  KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
#
#                             영문 종목명         상장일    시장구분 증권구분    소속부 주식종류  액면가  \
# 0  Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권  벤처기업부  보통주  500
#
#      상장주식수
# 0  8312766

# %%
inds = df[df['한글 종목명'].str.contains('우선주')].index

# %%
dfn = df.drop(inds)

# %%
dfn
# Out:
#               표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0     KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1     KR7131100000  131100     (주)스카이이앤엠   스카이이앤엠
# 2     KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 3     KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 4     KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# ...            ...     ...           ...      ...
# 2607  KR7189980006  189980        흥국에프엔비   흥국에프엔비
# 2610  KR7000540005  000540   흥국화재해상보험보통주     흥국화재
# 2611  KR7003280005  003280       흥아해운보통주     흥아해운
# 2612  KR7037440005  037440    희림종합건축사사무소       희림
# 2613  KR7238490007  238490            힘스       힘스
#
#                                영문 종목명         상장일    시장구분 증권구분          소속부  \
# 0     Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부
# 1                   SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)
# 2               POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부
# 3                AJ Networks Co.,Ltd.  2015/08/21   KOSPI   주권          NaN
# 4                   AK Holdings, Inc.  1999/08/11   KOSPI   주권          NaN
# ...                               ...         ...     ...  ...          ...
# 2607            HYUNGKUK F&B Co., Ltd  2015/08/07  KOSDAQ   주권        중견기업부
# 2610     HeungkukFire&MarineInsurance  1974/12/05   KOSPI   주권          NaN
# 2611                   HeungaShipping  1976/06/29   KOSPI   주권          NaN
# 2612     Heerim Architects & Planners  2000/02/03  KOSDAQ   주권        중견기업부
# 2613                   HIMS CO., LTD.  2017/07/20  KOSDAQ   주권        우량기업부
#
#      주식종류   액면가      상장주식수
# 0     보통주   500    8312766
# 1     보통주   500   11642629
# 2     보통주   500   41642703
# 3     보통주  1000   46822295
# 4     보통주  5000   13247561
# ...   ...   ...        ...
# 2607  보통주   100   39997771
# 2610  보통주  5000   64242645
# 2611  보통주   500  240424899
# 2612  보통주   500   13922475
# 2613  보통주   500   11312236
#
# [2491 rows x 12 columns]

# %%
codes = dfn.단축코드

# %%
# for code in codes:
#     fs = dart.fs.extract(corp_code=code, bgn_de='20120101')

# %%
for code in codes:
    comp = corp_list.find_by_stock_code(code)
    print(comp)
# Out:
# [00568188]마이크로컨텍솔
# [00814786]스카이이앤엠
# [00128111]포스코엠텍
# [00365387]AJ네트웍스
# [00125080]AK홀딩스
# [01263022]BGF리테일
# [00219097]BGF
# [00858364]BNK금융지주
# [00122579]BYC
# [00148540]CJ
# [00129013]CJ씨푸드
# [00380429]CMG제약
# [00149026]CS홀딩스
# [00163345]DB
# [00115694]DB금융투자
# [00159102]DB손해보험
# [00160843]DB하이텍
# [00878915]DGB금융지주
# [00118345]디아이동일
# [00128971]DL건설
# [00109693]DL
# [01524093]DL이앤씨
# [00110608]DSR
# [00151298]DSR제강
# [00165583]E1
# [01437186]ESR켄달스퀘어리츠
# [00175623]ES큐브
# [01568413]F&F
# [00126487]F&F 홀딩스
# [00120030]GS건설
# [00500254]GS
# [00164636]HDC
# [01310269]HDC현대산업개발
# [00633835]HJ중공업
# [00154426]아이에이치큐
# [00980122]JB금융지주
# [00225706]JW생명과학
# [00149947]JW중외제약
# [00632304]JW홀딩스
# [00688996]KB금융
# [00157539]KB오토시스
# [00103042]케이씨티시
# [00111218]KD
# [00115676]KG동부제철
# [00101220]KG케미칼
# [00193009]KH 필룩스
# [00159740]KISCO홀딩스
# [00191472]KPX케미칼
# [00587466]KPX홀딩스
# [00112378]KR모터스
# [00593032]LF
# [00105873]LG디스플레이
# [00120021]LG
# [00356370]LG생활건강
# [01515323]LG에너지솔루션
# [00231363]LG유플러스
# [00105961]LG이노텍
# [00401731]LG전자
# [00356361]LG화학
# [00503668]LIG넥스원
# [00105855]엘에스일렉트릭
R7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1     KR7131100000  131100     (주)스카이이앤엠   스카이이앤엠
# 2     KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 3     KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 4     KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# ...            ...     ...           ...      ...
# 2607  KR7189980006  189980        흥국에프엔비   흥국에프엔비
# 2610  KR7000540005  000540   흥국화재해상보험보통주     흥국화재
# 2611  KR7003280005  003280       흥아해운보통주     흥아해운
# 2612  KR7037440005  037440    희림종합건축사사무소       희림
# 2613  KR7238490007  238490            힘스       힘스
#
#                                영문 종목명         상장일    시장구분 증권구분          소속부  \
# 0     Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부
# 1                   SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)
# 2               POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부
# 3                AJ Networks Co.,Ltd.  2015/08/21   KOSPI   주권          NaN
# 4                   AK Holdings, Inc.  1999/08/11   KOSPI   주권          NaN
# ...                               ...         ...     ...  ...          ...
# 2607            HYUNGKUK F&B Co., Ltd  2015/08/07  KOSDAQ   주권        중견기업부
# 2610     HeungkukFire&MarineInsurance  1974/12/05   KOSPI   주권          NaN
# 2611                   HeungaShipping  1976/06/29   KOSPI   주권          NaN
# 2612     Heerim Architects & Planners  2000/02/03  KOSDAQ   주권        중견기업부
# 2613                   HIMS CO., LTD.  2017/07/20  KOSDAQ   주권        우량기업부
#
#      주식종류   액면가      상장주식수
# 0     보통주   500    8312766
# 1     보통주   500   11642629
# 2     보통주   500   41642703
# 3     보통주  1000   46822295
# 4     보통주  5000   13247561
# ...   ...   ...        ...
# 2607  보통주   100   39997771
# 2610  보통주  5000   64242645
# 2611  보통주   500  240424899
# 2612  보통주   500   13922475
# 2613  보통주   500   11312236
#
# [2491 rows x 12 columns]

# %%
names = dfn['한글 종목약명']

# %%
for name in names:
# Out:
# [[00568188]마이크로컨텍솔]
# [[00814786]스카이이앤엠]
# [[00128111]포스코엠텍]
# [[00365387]AJ네트웍스]
# [[00125080]AK홀딩스]
# [[01263022]BGF리테일]
# [[00219097]BGF, [01263022]BGF리테일]
# [[00858364]BNK금융지주]
# [[00122579]BYC]
# [[01325289]CJCGVVIETNAMHOLDINGSCO.,LTD, [00129013]CJ씨푸드, [00357120]CJ푸드빌, [00148540]CJ, [00303873]CJ CGV, [00635134]CJ제일제당, [00127954]CJ프레시웨이, [00265324]CJ ENM, [01071041]CJ 바이오사이언스, [00113410]CJ대한통운]
# [[00129013]CJ씨푸드]
# [[00380429]CMG제약]
# [[00149026]CS홀딩스]
# [[00544151]KDBCLeasingReceivablesCorp.IPlc,산은캐피탈외화리스유동화, [01386226]LANDBANKOFTHEPHILIPPINES, [00160843]DB하이텍, [01505469]DB금융스팩9호, [01505450]DB금융스팩8호, [00168933]DB생명보험, [01605088]DB김준기문화재단, [00229058]DB캐피탈, [00163345]DB, [00159102]DB손해보험, [00115694]DB금융투자]
# [[00115694]DB금융투자]
# [[00159102]DB손해보험]
# [[00160843]DB하이텍]
# [[00878915]DGB금융지주]
# None
# [[00128971]DL건설]
R7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1    KR7131100000  131100     (주)스카이이앤엠   스카이이앤엠
# 2    KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 3    KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 4    KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# ..            ...     ...           ...      ...
# 894  KR7263810004  263810          상신전자     상신전자
# 895  KR7089980007  089980        상아프론테크   상아프론테크
# 896  KR7042940007  042940         상지카일룸    상지카일룸
# 897  KR7042600007  042600          새로닉스     새로닉스
# 898  KR7075180000  075180       새론오토모티브  새론오토모티브
#
#                               영문 종목명         상장일    시장구분 증권구분          소속부  \
# 0    Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부
# 1                  SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)
# 2              POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부
# 3               AJ Networks Co.,Ltd.  2015/08/21   KOSPI   주권          NaN
# 4                  AK Holdings, Inc.  1999/08/11   KOSPI   주권          NaN
# ..                               ...         ...     ...  ...          ...
# 894    Sangshin Electronics Co.,Ltd.  2017/10/16  KOSDAQ   주권        중견기업부
# 895         SANG-A FRONTEC CO., LTD.  2011/07/21  KOSDAQ   주권        우량기업부
# 896              Sangji Caelum, Inc.  2000/10/19  KOSDAQ   주권        중견기업부
# 897              SERONICS. CO., LTD.  2002/10/01  KOSDAQ   주권        중견기업부
# 898      SaeronAutomotiveCorporation  2005/10/21   KOSPI   주권          NaN
#
#     주식종류   액면가     상장주식수
# 0    보통주   500   8312766
# 1    보통주   500  11642629
# 2    보통주   500  41642703
# 3    보통주  1000  46822295
# 4    보통주  5000  13247561
# ..   ...   ...       ...
# 894  보통주   500  14244718
# 895  보통주   500  15989037
# 896  보통주   500  83058257
# 897  보통주   500  12423574
# 898  보통주   500  19200000
#
# [830 rows x 12 columns]

# %%
dfn.iloc

# %%
df[df.str.contains('우선주')].index
# Out:
# Int64Index([   8,   10,   11,   13,   20,   24,   27,   36,   45,   46,
#             ...
#             2498, 2503, 2511, 2526, 2538, 2539, 2540, 2558, 2608, 2609],
#            dtype='int64', length=123)

# %%
df.str.contains('우선주')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2609     True
# 2610    False
# 2611    False
# 2612    False
# 2613    False
# Name: 한글 종목명, Length: 2614, dtype: bool

# %%
# Open DART API KEY 설정
api_key = '42a0d56f8478f24dffa336a5ed159b5f51c689f8'
dart.set_api_key(api_key=api_key)

# DART 에 공시된 회사 리스트 불러오기
corp_list = dart.get_corp_list()
# Out:
# Output()
# Output()
# Output()

# %%
df = pd.read_csv('stocks.csv', encoding='euckr')

# %%
inds = df[df['한글 종목명'].str.contains('우선주')].index
dfn = df.drop(inds)
names = dfn['한글 종목약명']

# %%
names[names == 'DB하이텍']
# Out:
# 21    DB하이텍
# Name: 한글 종목약명, dtype: object

# %%
for name in names[22:830]:
    try:
        company = corp_list.find_by_corp_name(name, exactly=True)[0]
        fs = company.extract_fs(bgn_de='20100101')
        filename = f'{name}.xlsx'
        path = ''
        fs.save(filename=filename)
    except:
        pass
# Out:
# Annual reports:   0%|          | 0/8 [00:00<?, ?report/s]
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20210319000451', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2020.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20210319', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20200330001416', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2019.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20200330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20190329002830', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2018.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20190329', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20180330002563', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2017.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20180330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20170330000526', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2016.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20170330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20160330002067', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2015.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20160330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20150331001765', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2014.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20150331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20140331001803', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2013.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20140331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130329001447', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2012.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20130329', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20120330000863', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2011.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20120330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110331001758', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '[첨부추가]사업보고서 (2010.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20110331', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100331001429', 'corp_code': '00151298', 'corp_name': 'DSR제강', 'stock_code': '069730', 'corp_cls': 'Y', 'report_nm': '[첨부추가]사업보고서 (2009.12)', 'flr_nm': 'DSR제강', 'rcept_dt': '20100331', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/13 [00:00<?, ?report/s]
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 5 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 4 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 3 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 2 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 5 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 4 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 3 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 2 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1242, in analyze_report
#     if separate is False and not xbrl.exist_consolidated():
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\xbrl\dart_xbrl.py", line 217, in exist_consolidated
#     cls_list = info_table.cls
# AttributeError: 'NoneType' object has no attribute 'cls'
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130329002736', 'corp_code': '00165583', 'corp_name': 'E1', 'stock_code': '017940', 'corp_cls': 'Y', 'report_nm': '[기재정정]사업보고서 (2010.12)', 'flr_nm': 'E1', 'rcept_dt': '20130401', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 5 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 4 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 3 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# 2 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2009-12-31/xbrl-dart-gaap-ci-2009-12-31.xsd
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 5 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 4 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 3 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# 2 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2009-12-31/xbrl-dart-gcd-2009-12-31.xsd
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1242, in analyze_report
#     if separate is False and not xbrl.exist_consolidated():
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\xbrl\dart_xbrl.py", line 217, in exist_consolidated
#     cls_list = info_table.cls
# AttributeError: 'NoneType' object has no attribute 'cls'
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130329002730', 'corp_code': '00165583', 'corp_name': 'E1', 'stock_code': '017940', 'corp_cls': 'Y', 'report_nm': '[기재정정]사업보고서 (2009.12)', 'flr_nm': 'E1', 'rcept_dt': '20130401', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2007-12-31/xbrl-dart-gaap-ci-2007-12-31.xsd
# 5 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2007-12-31/xbrl-dart-gaap-ci-2007-12-31.xsd
# 4 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2007-12-31/xbrl-dart-gaap-ci-2007-12-31.xsd
# 3 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2007-12-31/xbrl-dart-gaap-ci-2007-12-31.xsd
# 2 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gaap/ci/2007-12-31/xbrl-dart-gaap-ci-2007-12-31.xsd
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2007-12-31/xbrl-dart-gcd-2007-12-31.xsd
# 5 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2007-12-31/xbrl-dart-gcd-2007-12-31.xsd
# 4 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2007-12-31/xbrl-dart-gcd-2007-12-31.xsd
# 3 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2007-12-31/xbrl-dart-gcd-2007-12-31.xsd
# 2 retries remaining
# Remote end closed connection without response
# unsuccessful retrieval of http://xbrl-dart.fss.or.kr/kr/dart/gcd/2007-12-31/xbrl-dart-gcd-2007-12-31.xsd
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1242, in analyze_report
#     if separate is False and not xbrl.exist_consolidated():
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\xbrl\dart_xbrl.py", line 217, in exist_consolidated
#     cls_list = info_table.cls
# AttributeError: 'NoneType' object has no attribute 'cls'
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20130329002705', 'corp_code': '00165583', 'corp_name': 'E1', 'stock_code': '017940', 'corp_cls': 'Y', 'report_nm': '[기재정정]사업보고서 (2008.12)', 'flr_nm': 'E1', 'rcept_dt': '20130401', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/2 [00:00<?, ?report/s]
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110331000343', 'corp_code': '00175623', 'corp_name': 'ES큐브', 'stock_code': '050120', 'corp_cls': 'K', 'report_nm': '사업보고서 (2010.12)', 'flr_nm': 'ES큐브', 'rcept_dt': '20110331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100331000149', 'corp_code': '00175623', 'corp_name': 'ES큐브', 'stock_code': '050120', 'corp_cls': 'K', 'report_nm': '사업보고서 (2009.12)', 'flr_nm': 'ES큐브', 'rcept_dt': '20100331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1415: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110429001060', 'corp_code': '00120030', 'corp_name': 'GS건설', 'stock_code': '006360', 'corp_cls': 'Y', 'report_nm': '[기재정정]사업보고서 (2010.12)', 'flr_nm': 'GS건설', 'rcept_dt': '20110429', 'rm': '연'}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1401, in extract
#     nstatements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
# ...
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20110331002618', 'corp_code': '00220561', 'corp_name': '광주신세계', 'stock_code': '037710', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2010.12)', 'flr_nm': '광주신세계', 'rcept_dt': '20110331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# http.client.RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\util\retry.py", line 532, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\packages\six.py", line 769, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 1371, in getresponse
#     response.begin()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\bitcamp\anaconda3\lib\http\client.py", line 288, in _read_status
#     raise RemoteDisconnected("Remote end closed connection without"
# urllib3.exceptions.ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1248, in analyze_report
#     fs_df = analyze_html(report, fs_tp=fs_tp, separate=separate, lang=lang)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 615, in analyze_html
#     count, fs_table = report_find_all(report, query, fs_tp, separate)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 556, in report_find_all
#     searched = report.find_all(**query)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 371, in find_all
#     dataset[s] = func_set[s]()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 355, in attached_reports
#     res = [y for x in self.attached_reports for y in x.find_all(**kwargs) if determinant(x.info['rpt_nm'])]
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 273, in attached_reports
#     self.extract_attached_reports()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 286, in extract_attached_reports
#     self._get_report()
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\filings\reports.py", line 109, in _get_report
#     resp = request.get(url=self._REPORT_URL_, payload=payload, referer=self._DART_URL_)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 173, in get
#     return self.request(url=url, method='GET', payload=payload, referer=referer, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\utils\request.py", line 143, in request
#     resp = self.s.send(prepped, stream=stream, timeout=timeout)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\requests\adapters.py", line 498, in send
#     raise ConnectionError(err, request=request)
# requests.exceptions.ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20100331001811', 'corp_code': '00220561', 'corp_name': '광주신세계', 'stock_code': '037710', 'corp_cls': 'Y', 'report_nm': '사업보고서 (2009.12)', 'flr_nm': '광주신세계', 'rcept_dt': '20100331', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20210312000322', 'corp_code': '00104120', 'corp_name': '광진실업', 'stock_code': '026910', 'corp_cls': 'K', 'report_nm': '사업보고서 (2020.12)', 'flr_nm': '광진실업', 'rcept_dt': '20210312', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20200327000095', 'corp_code': '00104120', 'corp_name': '광진실업', 'stock_code': '026910', 'corp_cls': 'K', 'report_nm': '사업보고서 (2019.12)', 'flr_nm': '광진실업', 'rcept_dt': '20200327', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20190327000980', 'corp_code': '00104120', 'corp_name': '광진실업', 'stock_code': '026910', 'corp_cls': 'K', 'report_nm': '사업보고서 (2018.12)', 'flr_nm': '광진실업', 'rcept_dt': '20190327', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20180329001112', 'corp_code': '00104120', 'corp_name': '광진실업', 'stock_code': '026910', 'corp_cls': 'K', 'report_nm': '사업보고서 (2017.12)', 'flr_nm': '광진실업', 'rcept_dt': '20180329', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20170330000641', 'corp_code': '00104120', 'corp_name': '광진실업', 'stock_code': '026910', 'corp_cls': 'K', 'report_nm': '사업보고서 (2016.12)', 'flr_nm': '광진실업', 'rcept_dt': '20170330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)
# Traceback (most recent call last):
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1381, in extract
#     statements = analyze_report(report=report,
#   File "C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py", line 1243, in analyze_report
#     raise NotFoundConsolidated('Could not find consolidated financial statements')
# dart_fss.errors.errors.NotFoundConsolidated: Could not find consolidated financial statements
# C:\Users\bitcamp\anaconda3\lib\site-packages\dart_fss\fs\extract.py:1397: RuntimeWarning: Unable to extract financial statements: {'rcp_no': '20160330004535', 'corp_code': '00104120', 'corp_name': '광진실업', 'stock_code': '026910', 'corp_cls': 'K', 'report_nm': '사업보고서 (2015.12)', 'flr_nm': '광진실업', 'rcept_dt': '20160330', 'rm': ''}.
#   warnings.warn(warnings_text, RuntimeWarning)

# %%
df = pd.read_csv('stocks.csv', encoding='euckr')
inds = df[df['한글 종목명'].str.contains('우선주')].index
dfn = df.drop(inds)
names = dfn['한글 종목약명']

# %%
company
# Out:
# [00878915]DGB금융지주

# %%
dfn.head(20)
# Out:
#             표준코드    단축코드        한글 종목명  한글 종목약명  \
# 0   KR7098120009  098120  (주)마이크로컨텍솔루션  마이크로컨텍솔
# 1   KR7131100000  131100     (주)스카이이앤엠   스카이이앤엠
# 2   KR7009520008  009520      (주)포스코엠텍    포스코엠텍
# 3   KR7095570008  095570     AJ네트웍스보통주   AJ네트웍스
# 4   KR7006840003  006840      AK홀딩스보통주    AK홀딩스
# 5   KR7282330000  282330     BGF리테일보통주   BGF리테일
# 6   KR7027410000  027410        BGF보통주      BGF
# 7   KR7138930003  138930    BNK금융지주보통주  BNK금융지주
# 9   KR7001460005  001460        BYC보통주      BYC
# 12  KR7001040005  001040         CJ보통주       CJ
# 14  KR7011150000  011150      CJ씨푸드보통주    CJ씨푸드
# 15  KR7058820002  058820         CMG제약    CMG제약
# 16  KR7000590000  000590      CS홀딩스보통주    CS홀딩스
# 17  KR7012030003  012030    DB Inc.보통주       DB
# 18  KR7016610008  016610     DB금융투자보통주   DB금융투자
# 19  KR7005830005  005830     DB손해보험보통주   DB손해보험
# 21  KR7000990002  000990      DB하이텍보통주    DB하이텍
# 22  KR7139130009  139130    DGB금융지주보통주  DGB금융지주
# 23  KR7001530005  001530       DI동일보통주     DI동일
# 25  KR7001880004  001880       DL건설보통주     DL건설
#
#                                영문 종목명         상장일    시장구분 증권구분          소속부  \
# 0     Micro Contact Solution Co.,Ltd.  2008/09/23  KOSDAQ   주권        벤처기업부
# 1                   SKY E&M Co., Ltd.  2011/06/14  KOSDAQ   주권  관리종목(소속부없음)
# 2               POSCO M-TECH CO.,LTD.  1997/11/10  KOSDAQ   주권        우량기업부
# 3                AJ Networks Co.,Ltd.  2015/08/21   KOSPI   주권          NaN
# 4                   AK Holdings, Inc.  1999/08/11   KOSPI   주권          NaN
# 5                          BGF Retail  2017/12/08   KOSPI   주권          NaN
# 6                                 BGF  2014/05/19   KOSPI   주권          NaN
# 7            BNK Financial Group Inc.  2011/03/30   KOSPI   주권          NaN
# 9                                 BYC  1975/06/02   KOSPI   주권          NaN
# 12                           CJ Corp.  1973/06/29   KOSPI   주권          NaN
# 14               CJSEAFOODCORPORATION  1988/11/26   KOSPI   주권          NaN
# 15       CMG Pharmaceutical Co., Ltd.  2001/08/31  KOSDAQ   주권        우량기업부
# 16                         CSHOLDINGS  1975/12/22   KOSPI   주권          NaN
# 17                            DB Inc.  1993/01/06   KOSPI   주권          NaN
# 18  DB Financial Investment Co., LTD.  1988/06/27   KOSPI   주권          NaN
# 19                       DB INSURANCE  1973/06/28   KOSPI   주권          NaN
# 21                   DB HiTek Co.,LTD  1975/12/12   KOSPI   주권          NaN
# 22                DGB Financial Group  2011/06/07   KOSPI   주권          NaN
# 23                          DI DONGIL  1964/01/04   KOSPI   주권          NaN
# 25                     DLConstruction  1977/12/22   KOSPI   주권          NaN
#
#    주식종류   액면가      상장주식수
# 0   보통주   500    8312766
# 1   보통주   500   11642629
# 2   보통주   500   41642703
# 3   보통주  1000   46822295
# 4   보통주  5000   13247561
# 5   보통주  1000   17283906
# 6   보통주  1000   95716791
# 7   보통주  5000  325935246
# 9   보통주  5000     624615
# 12  보통주  5000   29176998
# 14  보통주   500   35930773
# 15  보통주   500  138892244
# 16  보통주  5000    1154482
# 17  보통주   500  201173933
# 18  보통주  5000   42446389
# 19  보통주   500   70800000
# 21  보통주  5000   44398588
# 22  보통주  5000  169145833
# 23  보통주  5000    2510655
# 25  보통주  5000   22053284

# %%
company = corp_list.find_by_corp_name('DI동일', exactly=True)[0]
company
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15168/1523345177.py in <module>
# ----> 1 company = corp_list.find_by_corp_name('DI동일', exactly=True)[0]
#       2 company
#
# TypeError: 'NoneType' object is not subscriptable

# %%
names
# Out:
# 0       마이크로컨텍솔
# 1        스카이이앤엠
# 2         포스코엠텍
# 3        AJ네트웍스
# 4         AK홀딩스
#          ...
# 2607     흥국에프엔비
# 2610       흥국화재
# 2611       흥아해운
# 2612         희림
# 2613         힘스
# Name: 한글 종목약명, Length: 2491, dtype: object

# %%
dfn = df.drop(df[df.str.contains('우선주')].index)

# %%
for s in dfn:
    print(s)
# Out:
# (주)마이크로컨텍솔루션
# (주)스카이이앤엠
# (주)포스코엠텍
# AJ네트웍스보통주
# AK홀딩스보통주
# BGF리테일보통주
# BGF보통주
# BNK금융지주보통주
# BYC보통주
# CJ보통주
# CJ씨푸드보통주
# CMG제약
# CS홀딩스보통주
# DB Inc.보통주
# DB금융투자보통주
# DB손해보험보통주
# DB하이텍보통주
# DGB금융지주보통주
# DI동일보통주
# DL건설보통주
# DL보통주
# DL이앤씨보통주
# DSR보통주
# DSR제강보통주
# E1보통주
# ESR켄달스퀘어리츠보통주
# ES큐브
# F&F보통주
# F&F홀딩스
# GS건설보통주
# GS보통주
# HDC보통주
# HDC현대산업개발보통주
# HJ중공업보통주
# IHQ보통주
# JB금융지주보통주
# JW생명과학보통주
# JW중외제약보통주
# JW홀딩스 보통주
# KB금융지주 보통주
# KB오토시스
# KCTC 보통주
# KD
# KG동부제철보통주
# KG케미칼보통주
# KH 필룩스보통주
# KISCO홀딩스보통주
# KPX케미칼보통주
# KPX홀딩스보통주
# KR모터스보통주
# LF보통주
# LG디스플레이보통주
# LG보통주
# LG생활건강보통주
# LG에너지솔루션보통주
# LG유플러스보통주
# LG이노텍보통주
# LG전자보통주
# LG화학보통주
# LIG넥스원보통주
# LS ELECTRIC보통주
# LS네트웍스보통주
# LS보통주
# LX인터내셔널보통주
# MH에탄올보통주
# NAVER보통주
# NHN보통주
# NH프라임리츠보통주
# NICE보통주
# NI스틸보통주
# NPC보통주
# OCI보통주
# S-Oil보통주
# SBI핀테크솔루션즈
# SGC에너지보통주
# SG글로벌보통주
# SHD보통주
# SH에너지화학보통주
# SIMPAC보통주
# SJM보통주
# SJM홀딩스보통주
# SKC보통주
# SK가스보통주
# SK네트웍스보통주
# SK디앤디보통주
# SK리츠보통주
# SK보통주
# SK스퀘어보통주
# SK아이이테크놀로지보통주
# SK이노베이션 보통주
# SK증권보통주
# SK케미칼보통주
# SK텔레콤보통주
# SNT모티브보통주
# SNT에너지보통주
# SNT중공업보통주
# SNT홀딩스보통주
# SPC삼립보통주
# STX보통주
# STX엔진보통주
# STX중공업보통주
# TBH글로벌보통주
# TCC스틸보통주
# WISCOM보통주
# 가비아
# 가온미디어
# 가온전선보통주
# 감성코퍼레이션
# 강남제비스코보통주
# 강스템바이오텍
# 강원랜드보통주
# 강원에너지
# 갤럭시아머니트리
# 갤럭시아에스엠보통주
# 경남스틸
# 경남제약
# 경농보통주
# 경동나비엔보통주
# 경동도시가스보통주
# 경동인베스트보통주
# 경동제약
# 경방보통주
# 경보제약보통주
# 경인양행보통주
# 경인전자보통주
# 경창산업
# 계룡건설산업보통주
# 계양전기보통주
# 고려산업보통주
# 고려시멘트
# 고려신용정보
# 고려아연보통주
# 고려제강보통주
# 고려제약
# 고바이오랩
# 고영테크놀러지
# 골드앤에스
# 골드퍼시픽
# 골프존
# 골프존뉴딘홀딩스
# 골프존데카
# 관악산업
# 광동제약보통주
# 광림
# 광명전기보통주
# 광전자보통주
# 광주신세계보통주
# 광진실업
# 교보10호기업인수목적
# 교보11호기업인수목적
# 교보9호기업인수목적
# 교보증권보통주
# 교촌에프앤비보통주
# 구영테크
# 국도화학보통주
# 국동보통주
# 국보디자인
# 국보보통주
# 국순당
# 국영지앤엠
# 국일신동
# 국일제지
# 국전약품
# 국제약품보통주
# 굿센
# 그랜드코리아레저보통주
# 그레이트리치과기유한공사
# 그리티
# 그린케미칼보통주
# 그린플러스
# 극동유화보통주
# 글로벌스탠다드테크놀로지
# 글로벌에스엠테크리미티드
# 글로벌텍스프리
# 글로본
# 금강공업보통주
# 금강철강
# 금비보통주
# 금양보통주
# 금호건설보통주
# 금호석유화학보통주
# 금호에이치티보통주
# 금호전기보통주
# 금호타이어보통주
# 금화피에스시
# 기가레인
# 기산텔레콤
# 기신정기 보통주
# 기아보통주
# 까뮤이앤씨보통주
# 까스텔바작
# 깨끗한나라보통주
# 나노
# 나노브릭
# 나노스
# 나노신소재
# 나노씨엠에스
# 나노엔텍
# 나노캠텍
# 나눔테크
# 나라소프트
# 나라엠앤디
# 나래나노텍
# 나무가
# 나무기술
# 나스미디어
# 나우아이비캐피탈
# 나우코스
# 나이벡
# 나이스디앤비
# 나이스정보통신
# 나이스평가정보
# 나인테크
# 남광토건보통주
# 남선알미늄보통주
# 남성보통주
# 남양유업보통주
# 남해화학보통주
# 남화산업
# 남화토건
# 내츄럴엔도텍
# 네오리진
# 네오셈
# 네오오토
# 네오위즈
# 네오위즈홀딩스
# 네오이뮨텍(Reg.S)
# 네오크레마
# 네오티스
# 네오팜
# 네오펙트
# 네온테크
# 네이블커뮤니케이션즈
# 네이처셀
# 네추럴에프앤피
# 네패스
# 네패스아크
# 넥센보통주
# 넥센타이어보통주
# 넥스턴바이오사이언스
# 넥스트비티
# 넥스트사이언스보통주
# 넥스트아이
# 넥스트엔터테인먼트월드
# 넥스틴
# 넥슨지티
# 넵튠
# 넷게임즈
# 넷마블보통주
# 노드메이슨
# 노랑풍선
# 노루페인트 보통주
# 노루홀딩스보통주
# 노바렉스
# 노바텍
# 노브메타파마
# 노터스
# 녹십자보통주
# 녹십자엠에스
# 녹십자웰빙
# 녹십자홀딩스보통주
# 녹원씨엔아이
# 농심보통주
# 농심홀딩스보통주
# 농업회사법인 아시아종묘
# 농업회사법인농우바이오
# 누리플랜
# 누리플렉스
# 뉴로스
# 뉴보텍
# 뉴인텍
# 뉴지랩파마
# 뉴트리
# 뉴파워프라즈마
# 뉴프렉스
# 다나와
# 다날
# 다믈멀티미디어
# 다보링크
# 다산네트웍스
# 다스코보통주
# 다우기술보통주
# 다우데이타
# 다원넥스뷰
# 다원시스
# 다이나믹디자인보통주
# 다이오진
# 단디바이오사이언스
# 대교보통주
# 대구백화점보통주
# 대덕보통주
# 대덕전자보통주
# 대동고려삼 주식회사
# 대동금속
# 대동기어
# 대동보통주
# 대동스틸
# 대동전자보통주
# 대륙제관
# 대림B&Co보통주
# 대림제지
# 대림통상보통주
# 대명소노시즌
# 대모엔지니어링
# 대보마그네틱
# 대봉엘에스
# 대상보통주
# 대상홀딩스 보통주
# 대성미생물연구소
# 대성산업보통주
# 대성에너지보통주
# 대성엘텍
# 대성창업투자
# 대성파인텍
# 대성홀딩스보통주
# 대신밸런스제10호기업인수목적
# 대신밸런스제11호기업인수목적
# 대신밸런스제7호기업인수목적
# 대신밸런스제8호기업인수목적
# 대신정보통신
# 대신증권보통주
# 대아티아이
# 대양금속보통주
# 대양전기공업
# 대양제지공업
# 대영포장보통주
# 대우건설보통주
# 대우전자부품보통주
# 대우조선해양보통주
# 대웅보통주
# 대웅제약보통주
# 대원
# 대원강업보통주
# 대원미디어
# 대원산업
# 대원전선보통주
# 대원제약보통주
# 대원화성보통주
# 대유
# 대유에이텍
# 대유에이피
# 대유플러스보통주
# 대정화금
# 대주산업
# 대주이엔티 주식회사
# 대주전자재료
# 대창단조보통주
# 대창보통주
# 대창솔루션
# 대창스틸
# 대한과학
# 대한광통신
# 대한그린파워
# 대한뉴팜
# 대한방직보통주
# 대한약품공업
# 대한유화보통주
# 대한전선보통주
# 대한제강 보통주
# 대한제당보통주
# 대한제분보통주
# 대한항공보통주
# 대한해운보통주
# 대한화섬보통주
# 대현보통주
# 대호에이엘보통주
# 대호특수강
# 대화제약
# 더 미동
# 더네이쳐홀딩스
# 더블유게임즈보통주
# 더블유아이
# 더블유에스아이
# 더에이치큐
# 더이앤엠
# 더존비즈온보통주
# 더콘텐츠온
# 덕산네오룩스
# 덕산테코피아
# 덕산하이메탈
# 덕성보통주
# 덕신하우징
# 덕양산업보통주
# 덕우전자
# 데브시스터즈
# 데이드림엔터테인먼트
# 데이타솔루션
# 데이터스트림즈
# 덱스터스튜디오
# 덴티스
# 덴티움보통주
# 도부마스크
# 도이치모터스
# 도화엔지니어링보통주
# 동구바이오제약
# 동국산업
# 동국알앤에스
# 동국에스엔씨
# 동국제강보통주
# 동국제약
# 동방보통주
# 동방선기
# 동방아그로보통주
# 동부건설보통주
# 동서보통주
# 동성제약보통주
# 동성케미컬보통주
# 동성화인텍
# 동신건설
# 동아쏘시오홀딩스보통주
# 동아에스티보통주
# 동아엘텍
# 동아지질보통주
# 동아타이어공업보통주
# 동아화성
# 동양고속보통주
# 동양보통주
# 동양생명보험보통주
# 동양에스텍
# 동양이엔피
# 동양철관보통주
# 동양파일
# 동양피스톤보통주
# 동우팜투테이블
# 동운아나텍
# 동원F&B보통주
# 동원개발
# 동원금속보통주
# 동원산업보통주
# 동원수산보통주
# 동원시스템즈보통주
# 동일고무벨트보통주
# 동일금속
# 동일기연
# 동일산업보통주
# 동일제강보통주
# 동일철강
# 동진쎄미켐
# 동화기업
# 동화약품보통주
# 두산밥캣보통주
# 두산보통주
# 두산중공업보통주
# 두산퓨얼셀보통주
# 두올보통주
# 듀오백
# 듀켐바이오
# 드래곤플라이
# 드림시큐리티
# 드림씨아이에스
# 드림어스컴퍼니
# 드림텍보통주
# 디딤
# 디바이스이엔지
# 디비금융제10호기업인수목적
# 디비금융제8호기업인수목적
# 디비금융제9호기업인수목적
# 디스플레이테크
# 디씨엠보통주
# 디아이보통주
# 디아이씨 보통주
# 디아이티
# 디아크
# 디알비동일보통주
# 디알젬
# 디알텍
# 디앤디플랫폼리츠보통주
# 디앤씨미디어
# 디어유
# 디에스씨인베스트먼트
# 디에스케이
# 디에이치피코리아
# 디에이테크놀로지
# 디에이피
# 디엑스앤브이엑스
# 디엔에이링크
# 디엔에프
# 디엠에스
# 디오
# 디와이디
# 디와이보통주
# 디와이씨
# 디와이파워보통주
# 디와이피엔에프
# 디이엔티
# 디젠스
# 디지아이
# 디지캡
# 디지탈옵틱
# 디지털대성
# 디지틀조선일보
# 디케이락
# 디케이앤디
# 디케이티
# 디티알오토모티브보통주
# 디티앤씨
# 디피코
# 딜리
# 딥노이드
# 라닉스
# 라온시큐어
# 라온테크
# 라온피플
# 라이온켐텍
# 라이트론
# 라이프사이언스테크놀로지
# 라이프시맨틱스
# 라파스
# 락앤락보통주
# 래몽래인
# 램테크놀러지
# 랩지노믹스
# 러셀
# 럭스피아
# 레고켐바이오사이언스
# 레드로버
# 레드캡투어
# 레몬
# 레이
# 레이언스
# 레이크머티리얼즈
# 레인보우로보틱스
# 렌딩머신
# 로보로보
# 로보스타
# 로보쓰리
# 로보티즈
# 로스웰인터내셔널
# 로지스몬
# 로지시스
# 로체시스템즈
# 롯데관광개발 보통주
# 롯데렌탈보통주
# 롯데리츠보통주
# 롯데손해보험보통주
# 롯데쇼핑 보통주
# 롯데정밀화학보통주
# 롯데정보통신보통주
# 롯데제과보통주
# 롯데지주보통주
# 롯데칠성음료보통주
# 롯데케미칼보통주
# 롯데푸드보통주
# 롯데하이마트보통주
# 루멘스
# 루켄테크놀러지스
# 루트락
# 루트로닉
# 룽투코리아
# 리노공업
# 리노스
# 리더스 기술투자
# 리더스코스메틱
# 리드코프
# 리메드
# 리파인
# 릭스솔루션
# 린드먼아시아인베스트먼트
# 링네트
# 링크제니시스
# 마니커보통주
# 마니커에프앤지
# 마이더스AI
# 마이크로디지탈
# 마이크로프랜드
# 마인즈랩
# 마크로밀엠브레인
# 마크로젠
# 만도보통주
# 만호제강보통주
# 맘스터치앤컴퍼니
# 매일유업
# 매일홀딩스
# 매직마이크로
# 매커스
# 맥스트
# 맥쿼리한국인프라투융자회사 보통주
# 머큐리
# 멀티캠퍼스
# 메가스터디
# 메가스터디교육
# 메가엠디
# 메드팩토
# 메디쎄이
# 메디아나
# 메디안디노스틱
# 메디앙스
# 메디젠휴먼케어
# 메디콕스
# 메디톡스
# 메디포스트
# 메디프론디비티
# 메리츠금융지주회사보통주
# 메리츠증권보통주
# 메리츠화재해상보험보통주
# 메이슨캐피탈
# 메지온
# 메카로
# 메타랩스보통주
# 메타바이오메드
# 멕아이씨에스
# 멜파스
# 명문제약 보통주
# 명성티엔에스
# 명신산업보통주
# 명진홀딩스
# 모나리자보통주
# 모나미보통주
# 모다이노칩
# 모두투어네트워크
# 모두투어리츠보통주
# 모바일리더
# 모바일어플라이언스
# 모베이스
# 모베이스전자
# 모비릭스
# 모비스
# 모아텍
# 모토닉보통주
# 모트렉스
# 모헨즈
# 무림에스피
# 무림페이퍼보통주
# 무림피앤피보통주
# 무진메디
# 무학보통주
# 문배철강보통주
# 미디어젠
# 미래나노텍
# 미래산업보통주
# 미래생명자원
# 미래아이앤지보통주
# 미래에셋글로벌리츠보통주
# 미래에셋대우기업인수목적 5호
# 미래에셋대우기업인수목적3호
# 미래에셋맵스리츠보통주
# 미래에셋맵스아시아퍼시픽부동산공모1호
# 미래에셋벤처투자
# 미래에셋생명보험보통주
# 미래에셋증권보통주
# 미래엔에듀파트너
# 미래컴퍼니
# 미스터블루
# 미애부
# 미원상사보통주
# 미원스페셜티케미칼보통주
# 미원홀딩스 보통주
# 미원화학보통주
# 미창석유공업보통주
# 미코
# 미코바이오메드
# 미투온
# 미투젠
# 민앤지
# 바다로19호선박투자회사
# 바디텍메드
# 바른손
# 바른손이앤에이
# 바른전자
# 바이넥스
# 바이브컴퍼니
# 바이오니아
# 바이오다인
# 바이오로그디바이스
# 바이오리더스
# 바이오솔루션
# 바이오스마트
# 바이오시네틱스
# 바이오인프라생명과학
# 바이오톡스텍
# 바이오프로테크
# 바이오플러스
# 바이온
# 바이옵트로
# 바이젠셀
# 바텍
# 박셀바이오
# 방림보통주
# 배럴
# 백광산업보통주
# 백금티앤에이
# 백산보통주
# 버킷스튜디오
# 범양건영보통주
# 베노홀딩스
# 베뉴지
# 베른
# 베셀
# 베스파
# 벽산보통주
# 보광산업
# 보라티알
# 보락보통주
# 보령제약보통주
# 보성파워텍
# 보해양조보통주
# 본느
# 볼빅
# 부-스타
# 부광약품보통주
# 부국증권보통주
# 부국철강 보통주
# 부방
# 부산산업보통주
# 부산주공보통주
# 뷰노
# 뷰웍스
# 브랜드엑스코퍼레이션
# 브레인즈컴퍼니
# 브리지텍
# 브릿지바이오테라퓨틱스
# 브이원텍
# 브이티지엠피
# 블루베리엔에프티
# 블루콤
# 블루탑
# 블리츠웨이
# 비나텍
# 비덴트
# 비디아이
# 비보존 헬스케어
# 비비씨
# 비비안보통주
# 비상교육 보통주
# 비씨월드제약
# 비아트론
# 비에이치
# 비에이치아이
# 비엔디생활건강
# 비엔지티
# 비엠티
# 비올
# 비즈니스온커뮤니케이션
# 비츠로셀
# 비츠로시스
# 비츠로테크
# 비케이탑스보통주
# 비투엔
# 비트나인
# 비트컴퓨터
# 비플라이소프트
# 비피도
# 빅솔론
# 빅텍
# 빅토리콘텐츠
# 빙그레보통주
# 빛샘전자
# 뿌리깊은나무들
# 사람인에이치알
# 사조대림보통주
# 사조동아원보통주
# 사조산업보통주
# 사조씨푸드보통주
# 사조오양보통주
# 삼강엠앤티
# 삼기
# 삼륭물산
# 삼목에스폼
# 삼보모터스
# 삼보산업
# 삼보판지
# 삼부토건보통주
# 삼성SDI보통주
# 삼성공조보통주
# 삼성기업인수목적4호
# 삼성머스트기업인수목적5호
# 삼성물산보통주
# 삼성바이오로직스보통주
# 삼성생명보험보통주
# 삼성에스디에스보통주
# 삼성엔지니어링보통주
# 삼성전기보통주
# 삼성전자보통주
# 삼성제약
# 삼성중공업보통주
# 삼성증권보통주
# 삼성출판사보통주
# 삼성카드 보통주
# 삼성화재해상보험보통주
# 삼아알미늄보통주
# 삼아제약
# 삼양사보통주
# 삼양식품보통주
# 삼양옵틱스
# 삼양통상보통주
# 삼양패키징보통주
# 삼양홀딩스보통주
# 삼에스코리아
# 삼영무역보통주
# 삼영에스앤씨
# 삼영엠텍
# 삼영이엔씨
# 삼영전자공업보통주
# 삼영화학공업보통주
# 삼원강재 보통주
# 삼익THK보통주
# 삼익악기보통주
# 삼일
# 삼일기업공사
# 삼일씨엔에스보통주
# 삼일제약보통주
# 삼정펄프 보통주
# 삼지전자
# 삼진
# 삼진엘앤디
# 삼진제약보통주
# 삼천당제약
# 삼천리보통주
# 삼천리자전거
# 삼표시멘트
# 삼현철강
# 삼호개발 보통주
# 삼화네트웍스
# 삼화왕관보통주
# 삼화전기보통주
# 삼화전자공업보통주
# 삼화콘덴서공업보통주
# 삼화페인트공업보통주
# 상보
# 상상인
# 상상인이안제2호기업인수목적
# 상상인인더스트리
# 상상인증권보통주
# 상신브레이크보통주
# 상신이디피
# 상신전자
# 상아프론테크
# 상지카일룸
# 새로닉스
# 새론오토모티브
# 샘씨엔에스
# 샘코
# 샘표보통주
# 샘표식품보통주
# 서남
# 서린바이오사이언스
# 서부티엔디
# 서산
# 서암기계공업
# 서연보통주
# 서연이화보통주
# 서연탑메탈
# 서울도시가스보통주
# 서울리거
# 서울바이오시스
# 서울반도체
# 서울식품공업보통주
# 서울옥션
# 서울전자통신
# 서울제약
# 서원보통주
# 서원인텍
# 서전기전
# 서진시스템
# 서진오토모티브
# 서플러스글로벌
# 서한
# 서호전기
# 서흥보통주
# 서희건설
# 석경에이티
# 선광
# 선데이토즈
# 선도전기보통주
# 선바이오
# 선앤엘보통주
# 선익시스템
# 선진보통주
# 선진뷰티사이언스
# 성광벤드
# 성도이엔지
# 성문전자보통주
# 성보화학보통주
# 성신양회보통주
# 성안보통주
# 성우전자
# 성우테크론
# 성우하이텍
# 성창기업지주보통주
# 성창오토텍
# 성호전자
# 세경하이테크
# 세기상사보통주
# 세동
# 세림비앤지
# 세명전기공업
# 세방보통주
# 세방전지보통주
# 세보엠이씨
# 세아베스틸보통주
# 세아제강보통주
# 세아제강지주보통주
# 세아특수강보통주
# 세아홀딩스보통주
# 세영디앤씨
# 세우글로벌보통주
# 세운메디칼
# 세원
# 세원물산
# 세원이앤씨보통주
# 세원정공보통주
# 세이브존I&C보통주
# 세종공업보통주
# 세종메디칼
# 세종텔레콤
# 세중
# 세진중공업보통주
# 세진티에스
# 세코닉스
# 세틀뱅크
# 세하보통주
# 세화피앤씨
# 센코
# 센트랄모텍보통주
# 센트럴인사이트보통주
# 셀레믹스
# 셀루메드
# 셀리드
# 셀리버리
# 셀바스에이아이
# 셀바스헬스케어
# 셀젠텍
# 셀트리온보통주
# 셀트리온제약
# 셀트리온헬스케어
# 소룩스
# 소리바다
# 소마젠
# 소프트센
# 소프트캠프
# 손오공
# 솔고바이오메디칼
# 솔루스첨단소재보통주
# 솔루에타
# 솔루엠보통주
# 솔본
# 솔브레인
# 솔브레인홀딩스
# 솔트룩스
# 송원산업보통주
# 쇼박스
# 수산아이앤티
# 수산중공업보통주
# 수성이노베이션
# 수젠텍
# 슈프리마
# 슈프리마아이디
# 슈프리마에이치큐
# 슈피겐코리아
# 스맥
# 스카이문스테크놀로지
# 스코넥엔터테인먼트
# 스킨앤스킨
# 스타플렉스
# 스템랩
# 스튜디오 산타클로스 엔터테인먼트
# 스튜디오드래곤 주식회사
# 스틱인베스트먼트보통주
# 스페코
# 스포츠서울
# 승일
# 시공테크
# 시그네틱스
# 시그넷이브이
# 시너지이노베이션
# 시노펙스
# 시디즈보통주
# 시스웍
# 시큐브
# 시큐센
# 시티랩스
# 신대양제지보통주
# 신도기연
# 신도리코보통주
# 신라교역보통주
# 신라섬유
# 신라에스지
# 신라젠
# 신성델타테크
# 신성이엔지보통주
# 신성통상보통주
# 신세계건설
# 신세계보통주
# 신세계아이앤씨 보통주
# 신세계인터내셔날보통주
# 신세계푸드보통주
# 신송홀딩스보통주
# 신신제약
# 신영와코루보통주
# 신영증권보통주
# 신영해피투모로우제5호기업인수목적
# 신영해피투모로우제6호기업인수목적
# 신원보통주
# 신원종합개발
# 신일전자보통주
# 신일제약
# 신진에스엠
# 신테카바이오
# 신풍제약보통주
# 신풍제지보통주
# 신한금융지주회사보통주
# 신한서부티엔디리츠보통주
# 신한알파리츠보통주
# 신한제6호기업인수목적
# 신한제7호기업인수목적
# 신한제8호기업인수목적
# 신화인터텍
# 신화콘텍
# 신흥보통주
# 신흥에스이씨
# 실리콘투
# 심텍
# 심텍홀딩스
# 싸이맥스
# 싸이버원
# 싸이토젠
# 쌍방울
# 쌍용C&E보통주
# 쌍용자동차보통주
# 쌍용정보통신
# 써니전자보통주
# 썬테크
# 썸에이지
# 쎄노텍
# 쎄니트
# 쎄트렉아이
# 쎌마테라퓨틱스보통주
# 쎌바이오텍
# 쏠리드
# 씨비아이
# 씨씨에스충북방송
# 씨아이에스
# 씨아이테크보통주
# 씨알푸드
# 씨앗
# 씨앤씨인터내셔널
# 씨앤에스링크
# 씨앤에이치
# 씨앤지하이테크
# 씨앤투스성진
# 씨앤티85
# 씨에스
# 씨에스베어링
# 씨에스에이코스믹
# 씨에스윈드보통주
# 씨엔알리서치
# 씨엔티드림
# 씨엔플러스
# 씨엠에스에듀
# 씨오더블유오엔
# 씨유메디칼시스템
# 에스에스알
# 에스에이엠티
# 에스에이티
# 에스에이티
# 에스에프에이
# 에스에프에이반도체
# 에스엔유프리시젼
# 에스엔케이폴리텍
# 에스엘바이오닉스
# 에스엘보통주
# 에스엘에스바이오
# 에스엠라이프디자인그룹
# 에스엠비나
# 에스엠엔터테인먼트
# 에스엠컬처앤콘텐츠
# 에스엠코어
# 에스와이
# 에스원보통주
# 에스제이그룹
# 에스제이켐
# 에스지세계물산보통주
# 에스지씨이테크건설
# 에스지에이
# 에스지에이 솔루션즈
# 에스지엔지
# 에스지이
# 에스케이디스커버리보통주
# 에스케이렌터카보통주
# 에스케이바이오사이언스보통주
# 에스케이바이오팜보통주
# 에스케이씨에스
# 에스케이제5호기업인수목적
# 에스케이제6호기업인수목적
# 에스케이하이닉스보통주
# 에스코넥
# 에스텍
# 에스텍파마
# 에스트래픽
# 에스티아이
# 에스티오
# 에스티큐브
# 에스티팜
# 에스폴리텍
# 에스퓨얼셀
# 에스피시스템스
# 에스피지
# 에쎈테크
# 에쓰씨엔지니어링보통주
# 에어부산보통주
# 에이디엠코리아
# 에이디칩스
# 에이디테크놀로지
# 에이루트
# 에이블씨엔씨보통주
# 에이비엘바이오
# 에이비온
# 에이비프로바이오
# 에이스침대
# 에이스테크놀로지
# 에이스토리
# 에이에프더블류
# 에이엔피보통주
# 에이원알폼
# 에이자기관리부동산투자회사보통주
# 에이치디씨랩스보통주
# 에이치디씨현대이피보통주
# 에이치비솔루션
# 에이치비테크놀러지
# 에이치시티
# 에이치알에스
# 에이치앤비디자인
# 에이치에스디엔진보통주
# 에이치엔에스하이텍
# 에이치엔티일렉트로닉스
# 에이치엘비
# 에이치엘비생명과학
# 에이치엘비제약
# 에이치엘비테라퓨틱스
# 에이치엘비파워
# 에이치엘사이언스
# 에이치엠씨아이비제4호기업인수목적
# 에이치엠씨아이비제5호기업인수목적
# 에이치엠엠보통주
# 에이치케이
# 에이치케이이노엔
# 에이치피오
# 에이테크솔루션
# 에이텍
# 에이텍티앤
# 에이트원
# 에이티넘인베스트먼트
# 에이티세미콘
# 에이팩트
# 에이펙스인텍
# 에이프로
# 에이프로젠메디신보통주
# 에이프로젠제약보통주
# 에이프로젠헬스케어앤게임즈
# 에이플러스에셋보통주
# 에이피시스템
# 에이피에스홀딩스
# 에이피위성
# 에이피티씨
# 에치에프알
# 에코마케팅
# 에코바이오홀딩스
# 에코캡
# 에코프로
# 에코프로비엠
# 에코프로에이치엔
# 에코플라스틱
# 에프알텍
# 에프앤가이드
# 에프앤리퍼블릭
# 에프에스엔
# 에프에스티
# 에프엔씨엔터테인먼트
# 에프엔에스테크
# 엑사이엔씨
# 엑세스바이오
# 엑셈
# 엑스큐어
# 엑시콘
# 엔바이오니아
# 엔브이에이치코리아
# 엔비티
# 엔솔바이오사이언스
# 엔시스
# 엔시트론
# 엔씨소프트보통주
# 엔에스
# 엔에스쇼핑보통주
# 엔에스엔
# 엔에스엠
# 엔에스컴퍼니
# 엔에이치기업인수목적18호
# 엔에이치기업인수목적19호보통주
# 엔에이치기업인수목적20호
# 엔에이치기업인수목적21호
# 엔에이치기업인수목적22호
# 엔에이치엔벅스
# 엔에이치엔한국사이버결제
# 엔에이치올원리츠보통주
# 엔에이치투자증권보통주
# 엔에프씨
# 엔이능률
# 엔젠바이오
# 엔지브이아이
# 엔지스테크널러지
# 엔지켐생명과학
# 엔케이 보통주
# 엔케이맥스
# 엔켐
# 엔텔스
# 엔투텍
# 엔피
# 엔피디
# 엔피케이
# 엘디티
# 엘리비젼
# 엘브이엠씨홀딩스보통주
# 엘비루셈
# 엘비세미콘
# 엘아이에스
# 엘앤씨바이오
# 엘앤에프
# 엘앤케이바이오메드
# 엘에스전선아시아보통주
# 엘에이티
# 엘엑스세미콘
# 엘엑스하우시스보통주
# 엘엑스홀딩스보통주
# 엘엠에스
# 엘오티베큠
# 엘지헬로비전보통주
# 엘컴텍
# 엘티씨
# 엠게임
# 엠로
# 엠벤처투자
# 엠씨넥스보통주
# 엠아이텍
# 엠앤씨생명과학
# 엠에스씨
# 엠에스오토텍
# 엠에프엠코리아
# 엠케이전자
# 엠투아이코퍼레이션
# 엠투엔
# 엠플러스
# 엠피대산
# 연우
# 연이비앤티
# 영림원소프트랩
# 영보화학보통주
# 영신금속공업
# 영우디에스피
# 영원무역보통주
# 영원무역홀딩스보통주
# 영진약품보통주
# 영풍보통주
# 영풍정밀
# 영풍제지보통주
# 영화금속보통주
# 영화테크
# 영흥보통주
# 예림당
# 예선테크
# 예스이십사
# 예스코홀딩스보통주
# 예스티
# 예스피치
# 오가닉티코스메틱스홀딩스컴퍼니리미티드
# 오공
# 오디텍
# 오뚜기보통주
# 오로라월드
# 오로스테크놀로지
# 오르비텍
# 오리엔탈정공
# 오리엔트바이오보통주
# 오리엔트정공
# 오리온보통주
# 오리온홀딩스보통주
# 오리콤
# 오비고
# 오상자이엘
# 오성첨단소재
# 오션브릿지
# 오션스톤
# 오스코텍
# 오스템
# 오스템임플란트
# 오이솔루션
# 오킨스전자
# 오텍
# 오토앤
# 오파스넷
# 오픈베이스
# 오하임아이엔티
# 올리패스
# 올릭스
# 옴니시스템
# 옵트론텍
# 옵티시스
# 옵티팜
# 와이더블유
# 와이더플래닛
# 와이비엠넷
# 와이솔
# 와이아이케이
# 와이어블
# 와이엔텍
# 와이엠씨
# 와이엠텍
# 와이엠티
# 와이오엠
# 와이제이엠게임즈
# 와이즈버즈
# 와이지-원
# 와이지엔터테인먼트
# 와이지플러스보통주
# 와이투솔루션보통주
# 와이티엔
# 와이팜
# 와토스 코리아
# 우리금융지주보통주
# 우리기술
# 우리기술투자
# 우리넷
# 우리들휴브레인보통주
# 우리로
# 우리바이오
# 우리산업
# 우리산업홀딩스
# 우리손에프앤지 농업회사법인
# 우리이앤엘
# 우리조명
# 우리종합금융보통주
# 우림피티에스
# 우성보통주
# 우수AMS
# 우신시스템보통주
# 우양
# 우원개발
# 우정바이오
# 우주일렉트로닉스
# 우진보통주
# 우진비앤지
# 우진아이엔에스보통주
# 우진플라임 보통주
# 웅진보통주
# 웅진씽크빅 보통주
# 원림보통주
# 원바이오젠
# 원방테크
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
name = '삼성전자'
company = corp_list.find_by_corp_name(name, exactly=True)[0]


fs = company.extract_fs(bgn_de='20100101')
# Out:
# Annual reports:   0%|          | 0/12 [00:00<?, ?report/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15168/1613602263.py in <module>
#       3
#       4
# ----> 5 fs = company.extract_fs(bgn_de='20100101')
#
# ~\anaconda3\lib\site-packages\dart_fss\corp\corp.py in extract_fs(self, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator, dataset, cumulative)
#     241
#     242          """
# --> 243         return extract(self.corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator, dataset, cumulative)
#
# ~\anaconda3\lib\site-packages\dart_fss\fs\extract.py in extract(corp_code, bgn_de, end_de, fs_tp, separate, report_tp, lang, separator, dataset, cumulative)
#    1399                     else:
#    1400                         try :
# -> 1401                             nstatements = analyze_report(report=report,
#    1402                                                          fs_tp=fs_tp,
#    1403                                                          separate=separate,
#
# ~\anaconda3\lib\site-packages\dart_fss\fs\extract.py in analyze_report(report, fs_tp, separate, lang, separator, dataset)
#    1234     year = int(report.rcept_dt[:4])
#    1235     if year > 2011 and dataset == 'xbrl':
# -> 1236         xbrl = report.xbrl
#    1237     else:
#    1238         xbrl = None
#
# ~\anaconda3\lib\site-packages\dart_fss\filings\reports.py in xbrl(self)
#     375     def xbrl(self):
#     376         if self._xbrl is None:
# --> 377             self.load_xbrl()
#     378         return self._xbrl
#     379
#
# ~\anaconda3\lib\site-packages\dart_fss\filings\reports.py in load_xbrl(self)
#     385                 try:
#     386                     file_path = download_xbrl(path=path, rcept_no=self.rcept_no)
# --> 387                     self._xbrl = get_xbrl_from_file(file_path)
#     388                 except FileNotFoundError:
#     389                     xbrl_attached = self._get_xbrl()
#
# ~\anaconda3\lib\site-packages\dart_fss\xbrl\xbrl.py in get_xbrl_from_file(file_path)
#      36         if not os.path.exists(arelle_app_dir):
#      37             os.makedirs(arelle_app_dir)
# ---> 38     model_xbrl = Cntlr.Cntlr().modelManager.load(file_path)
#      39     filename = file_path.split('\\')[-1]
#      40     xbrl = DartXbrl(filename, model_xbrl)
#
# ~\anaconda3\lib\site-packages\arelle\ModelManager.py in load(self, filesource, nextaction, taxonomyPackages, **kwargs)
#     156                 break # custom loader did the loading
#     157         if modelXbrl is None:  # use default xbrl loader
# --> 158             modelXbrl = ModelXbrl.load(self, filesource, nextaction, **kwargs)
#     159         self.modelXbrl = modelXbrl
#     160         self.loadedModelXbrls.append(self.modelXbrl)
#
# ~\anaconda3\lib\site-packages\arelle\ModelXbrl.py in load(modelManager, url, nextaction, base, useFileSource, errorCaptureLevel, **kwargs)
#      67         modelXbrl.closeFileSource= True
#      68
# ---> 69     modelXbrl.modelDocument = ModelDocument.load(modelXbrl, url, base, isEntry=True, **kwargs)
#      70
#      71 #    print('Model Document' + str(modelXbrl.modelDocument))
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     332                 modelDocument.linkbaseDiscover(rootNode)
#     333         elif _type == Type.INSTANCE:
# --> 334             modelDocument.instanceDiscover(rootNode)
#     335         elif _type == Type.INLINEXBRL:
#     336             # slow
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in instanceDiscover(self, xbrlElement)
#    1144
#    1145     def instanceDiscover(self, xbrlElement):
# -> 1146         self.schemaLinkbaseRefsDiscover(xbrlElement)
#    1147         if not self.skipDTS:
#    1148             self.linkbaseDiscover(xbrlElement,inInstance=True) # for role/arcroleRefs and footnoteLinks
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefsDiscover(self, tree)
#    1007             for element in tree.iterdescendants(tag=refln):
#    1008                 if isinstance(element,ModelObject):
# -> 1009                     self.schemaLinkbaseRefDiscover(element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefDiscover(self, element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
# -> 1012         return self.discoverHref(element, urlRewritePluginClass="ModelDocument.InstanceSchemaRefRewriter")
#    1013
#    1014     def linkbasesDiscover(self, tree):
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in discoverHref(self, element, nonDTS, urlRewritePluginClass)
#    1130                     for pluginMethod in pluginClassMethods(urlRewritePluginClass):
#    1131                         url = pluginMethod(self, url)
# -> 1132                 doc = _newDoc(self.modelXbrl, url, isDiscovered=not nonDTS, base=self.baseForElement(element), referringElement=element)
#    1133                 if not nonDTS and doc is not None and doc not in self.referencesDocument:
#    1134                     self.referencesDocument[doc] = ModelDocumentReference("href", element)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     325         elif _type == Type.SCHEMA:
#     326             # slow
# --> 327             modelDocument.schemaDiscover(rootNode, isIncluded, namespace)
#     328             #print("SCHEMA: {0:.2f} | {1} {2}".format(time()-s, isIncluded, namespace))
#     329         elif _type == Type.LINKBASE:
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscover(self, rootElement, isIncluded, namespace)
#     870         # self.definesUTR = any(ns == XbrlConst.utr for ns in rootElement.nsmap.values())
#     871         try:
# --> 872             self.schemaDiscoverChildElements(rootElement)
#     873         except (ValueError, LookupError) as err:
#     874             self.modelXbrl.modelManager.addToLog("discovery: {0} error {1}".format(
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     907                             self.linkbaseDiscover(modelObject)
#     908                 # recurse to children
# --> 909                 self.schemaDiscoverChildElements(modelObject)
#     910
#     911
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     907                             self.linkbaseDiscover(modelObject)
#     908                 # recurse to children
# --> 909                 self.schemaDiscoverChildElements(modelObject)
#     910
#     911
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     903                             self.modelXbrl.arcroleTypes[modelObject.arcroleURI].append(modelObject)
#     904                         elif ln == "linkbaseRef":
# --> 905                             self.schemaLinkbaseRefDiscover(modelObject)
#     906                         elif ln == "linkbase":
#     907                             self.linkbaseDiscover(modelObject)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefDiscover(self, element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
# -> 1012         return self.discoverHref(element, urlRewritePluginClass="ModelDocument.InstanceSchemaRefRewriter")
#    1013
#    1014     def linkbasesDiscover(self, tree):
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in discoverHref(self, element, nonDTS, urlRewritePluginClass)
#    1130                     for pluginMethod in pluginClassMethods(urlRewritePluginClass):
#    1131                         url = pluginMethod(self, url)
# -> 1132                 doc = _newDoc(self.modelXbrl, url, isDiscovered=not nonDTS, base=self.baseForElement(element), referringElement=element)
#    1133                 if not nonDTS and doc is not None and doc not in self.referencesDocument:
#    1134                     self.referencesDocument[doc] = ModelDocumentReference("href", element)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     330             # slow
#     331             if not AWESOME_MODS:
# --> 332                 modelDocument.linkbaseDiscover(rootNode)
#     333         elif _type == Type.INSTANCE:
#     334             modelDocument.instanceDiscover(rootNode)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in linkbaseDiscover(self, linkbaseElement, inInstance)
#    1061                                     nonDTS = linkElement.namespaceURI != XbrlConst.link or linkElement.localName != "loc"
#    1062                                     # only link:loc elements are discovered or processed
# -> 1063                                     href = self.discoverHref(linkElement, nonDTS=nonDTS)
#    1064                                     if href is None:
#    1065                                         if isStandardExtLink:
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in discoverHref(self, element, nonDTS, urlRewritePluginClass)
#    1130                     for pluginMethod in pluginClassMethods(urlRewritePluginClass):
#    1131                         url = pluginMethod(self, url)
# -> 1132                 doc = _newDoc(self.modelXbrl, url, isDiscovered=not nonDTS, base=self.baseForElement(element), referringElement=element)
#    1133                 if not nonDTS and doc is not None and doc not in self.referencesDocument:
#    1134                     self.referencesDocument[doc] = ModelDocumentReference("href", element)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     325         elif _type == Type.SCHEMA:
#     326             # slow
# --> 327             modelDocument.schemaDiscover(rootNode, isIncluded, namespace)
#     328             #print("SCHEMA: {0:.2f} | {1} {2}".format(time()-s, isIncluded, namespace))
#     329         elif _type == Type.LINKBASE:
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscover(self, rootElement, isIncluded, namespace)
#     870         # self.definesUTR = any(ns == XbrlConst.utr for ns in rootElement.nsmap.values())
#     871         try:
# --> 872             self.schemaDiscoverChildElements(rootElement)
#     873         except (ValueError, LookupError) as err:
#     874             self.modelXbrl.modelManager.addToLog("discovery: {0} error {1}".format(
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     907                             self.linkbaseDiscover(modelObject)
#     908                 # recurse to children
# --> 909                 self.schemaDiscoverChildElements(modelObject)
#     910
#     911
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     907                             self.linkbaseDiscover(modelObject)
#     908                 # recurse to children
# --> 909                 self.schemaDiscoverChildElements(modelObject)
#     910
#     911
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaDiscoverChildElements(self, parentModelObject)
#     903                             self.modelXbrl.arcroleTypes[modelObject.arcroleURI].append(modelObject)
#     904                         elif ln == "linkbaseRef":
# --> 905                             self.schemaLinkbaseRefDiscover(modelObject)
#     906                         elif ln == "linkbase":
#     907                             self.linkbaseDiscover(modelObject)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in schemaLinkbaseRefDiscover(self, element)
#    1010
#    1011     def schemaLinkbaseRefDiscover(self, element):
# -> 1012         return self.discoverHref(element, urlRewritePluginClass="ModelDocument.InstanceSchemaRefRewriter")
#    1013
#    1014     def linkbasesDiscover(self, tree):
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in discoverHref(self, element, nonDTS, urlRewritePluginClass)
#    1130                     for pluginMethod in pluginClassMethods(urlRewritePluginClass):
#    1131                         url = pluginMethod(self, url)
# -> 1132                 doc = _newDoc(self.modelXbrl, url, isDiscovered=not nonDTS, base=self.baseForElement(element), referringElement=element)
#    1133                 if not nonDTS and doc is not None and doc not in self.referencesDocument:
#    1134                     self.referencesDocument[doc] = ModelDocumentReference("href", element)
#
# ~\anaconda3\lib\site-packages\arelle\ModelDocument.py in load(modelXbrl, uri, base, referringElement, isEntry, isDiscovered, isIncluded, namespace, reloadCache, **kwargs)
#     108     else:
#     109         #print('filepath' + str(filepath))
# --> 110         filepath = modelXbrl.modelManager.cntlr.webCache.getfilename(mappedUri, reload=reloadCache, checkModifiedTime=kwargs.get("checkModifiedTime",False))
#     111         if filepath:
#     112             uri = modelXbrl.modelManager.cntlr.webCache.normalizeUrl(filepath)
#
# ~\anaconda3\lib\site-packages\arelle\WebCache.py in getfilename(self, url, base, reload, checkModifiedTime, normalize, filenameOnly)
#     315             timeNowStr = time.strftime('%Y-%m-%dT%H:%M:%S UTC', time.gmtime(timeNow))
#     316             retrievingDueToRecheckInterval = False
# --> 317             if not reload and os.path.exists(filepath):
#     318                 if url in self.cachedUrlCheckTimes and not checkModifiedTime:
#     319                     cachedTime = calendar.timegm(time.strptime(self.cachedUrlCheckTimes[url], '%Y-%m-%dT%H:%M:%S UTC'))
#
# ~\anaconda3\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except (OSError, ValueError):
#      21         return False
#
# KeyboardInterrupt:

# %%
name = '삼성전자'
company = corp_list.find_by_corp_name(name, exactly=True)[0]
company
# Out:
# [00126380]삼성전자

# %%
for s in dfn:
    name = f'{s}'
    company = corp_list.find_by_corp_name(name, exactly=True)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15168/3826093896.py in <module>
#       1 for s in dfn:
#       2     name = f'{s}'
# ----> 3     company = corp_list.find_by_corp_name(name, exactly=True)[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
name
# Out:
# '(주)마이크로컨텍솔루션'

# %%
name = '(주)마이크로컨텍솔루션'
corp_list.find_by_corp_name(name, exactly=True)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15168/4207103117.py in <module>
#       1 name = '(주)마이크로컨텍솔루션'
# ----> 2 corp_list.find_by_corp_name(name, exactly=True)[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
dfn
# Out:
# 0       (주)마이크로컨텍솔루션
# 1          (주)스카이이앤엠
# 2           (주)포스코엠텍
# 3          AJ네트웍스보통주
# 4           AK홀딩스보통주
#             ...
# 2607          흥국에프엔비
# 2610     흥국화재해상보험보통주
# 2611         흥아해운보통주
# 2612      희림종합건축사사무소
# 2613              힘스
# Name: 한글 종목명, Length: 2491, dtype: object

# %%
df1 = pd.read_excel('.\\fsdata\\대우건설.xlsx', sheet_name='Data_is')
df2 = pd.read_excel('.\\fsdata\\대우건설.xlsx', sheet_name='Data_cis')

# %%
df2_n = df2.T.drop(['Unnamed: 0', '[D410000] Statement of comprehensive income - Consolidated financial statements (Unit: KRW)', 'Unnamed: 3', 'Unnamed: 4','Unnamed: 5', 'Unnamed: 6', 'Unnamed: 
from openpyxl import Workbook, load_workbook
import pandas as pd
from openpyxl.utils import get_column_letter
from openpyxl.styles import Border, Side

# Company that you find
file = 'KPX케미칼.xlsx'

wb = load_workbook(file)
item_list = []

# 연도별 Data를 가져올 함수 설정
def get_data(r, ws, list):
    c = 2
    while ws.cell(2, c).value != None:
        y = ws.cell(1, c).value
        if y != None and y[:1] == '2':
            for i in range(10):
                list.append(ws.cell(r, c + i).value)
            break
        c += 1

# 제무상태표, 손익계산서, 현금흐름을 가져올 수 있는 함수설정
def get_fs_data(ws, fs_items, df_list):
    for fs_item in fs_items:
        temp_list = []
        r = 4
        while ws.cell(r, 2).value != None:
            if ws.cell(r, 2).value == fs_item:
                key = ws.cell(r, 2).value
                item = ws.cell(r, 3).value
                item_list.append(item)
                get_data(r, ws, temp_list)
            r += 1
        df = pd.DataFrame(temp_list, columns=[key], index=y_list)
        df_list.append(df)

# 재무상태표를 통해 년도를 List로 만들기
y_list = []
get_data(1, wb['Data_bs'], y_list)

# 각 데이터가 담긴 Dataframe 리스트를 담을 변수 지정
df_list = []

# 재무상태표 Data 가져오기
bs_items = ['ifrs-full_Assets', 'ifrs-full_CurrentAssets', 'ifrs-full_CashAndCashEquivalents',
            'dart_ShortTermTradeReceivable', 'ifrs-full_Inventories', 'ifrs-full_PropertyPlantAndEquipment',
            'ifrs-full_ShorttermBorrowings', 'ifrs-full_IssuedCapital', 'ifrs-full_RetainedEarnings',
            'ifrs-full_IntangibleAssetsOtherThanGoodwill', 'ifrs-full_CurrentLiabilities',
            'ifrs-full_Equity', 'ifrs-full_Liabilities']
get_fs_data(wb['Data_bs'], bs_items, df_list)

# 손익계산서 Data 가져오기
is_items = ['ifrs-full_Revenue', 'ifrs-full_GrossProfit', 'dart_OperatingIncomeLoss', 'ifrs-full_ProfitLoss']
get_fs_data(wb['Data_is'], is_items, df_list)

# 현금흐름 Data 가져오기
cf_items = ['ifrs-full_CashFlowsFromUsedInOperatingActivities',
            'ifrs-full_InterestPaidClassifiedAsOperatingActivities',
            'ifrs-full_CashFlowsFromUsedInInvestingActivities',
            'ifrs-full_CashFlowsFromUsedInFinancingActivities',
            'ifrs-full_ProceedsFromSalesOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities',
            'ifrs-full_PurchaseOfPropertyPlantAndEquipmentClassifiedAsInvestingActivities']
get_fs_data(wb['Data_cf'], cf_items, df_list)

# 각 데이터프레임 합치기
total_df = pd.concat(df_list, axis=1)

# 합쳐진 데이터 프레임 행/열 바꾸기
total_df = total_df.transpose()

# 재무비율 계산하여 행 추가하기
total_df.loc['Free Cash Flow'] = total_df.loc['ifrs-full_CashFlowsFromUsedInOperatingActivities'] + \
                                 total_df.loc['ifrs-full_ProceedsFromSalesOfPropertyPlantAndEquipmentClassified' \
                                              'AsInvestingActivities'] - \
                                 total_df.loc['ifrs-full_PurchaseOfPropertyPlantAndEquipmentClassifiedAsInvesting' \
                                              'Activities']
total_df.loc['재고자산회전율'] = total_df.loc['ifrs-full_Revenue'] / total_df.loc['ifrs-full_Inventories']
total_df.loc['이자보상배율'] = total_df.loc['dart_OperatingIncomeLoss'] / total_df.loc['ifrs-full_Interest' \
                                                                                 'PaidClassifiedAsOperatingActivities']
total_df.loc['ROA'] = total_df.loc['ifrs-full_ProfitLoss'] / total_df.loc['ifrs-full_Assets']
total_df.loc['ROE'] = total_df.loc['ifrs-full_ProfitLoss'] / total_df.loc['ifrs-full_Equity']
total_df.loc['유동비율'] = total_df.loc['ifrs-full_CurrentLiabilities'] / total_df.loc['ifrs-full_CurrentAssets']
total_df.loc['매출총이익율'] = total_df.loc['ifrs-full_GrossProfit'] / total_df.loc['ifrs-full_Revenue']
total_df.loc['영업이익율'] = total_df.loc['dart_OperatingIncomeLoss'] / total_df.loc['ifrs-full_Revenue']
total_df.loc['순이익율'] = total_df.loc['ifrs-full_ProfitLoss'] / total_df.loc['ifrs-full_Revenue']

# 컬럼과 항목 List의 길이차이
dif_len = len(total_df.iloc[:, [1]]) - len(item_list)

for dif in range(dif_len):
    item_list.append(0)

total_df['항목'] = item_list
col1 = total_df.columns[0:len(total_df.columns) - 1].to_list()
col2 = total_df.columns[-1:].to_list()
total_df = total_df[col2 + col1]

print(total_df)
total_df.to_excel('fs_analy.xlsx')

wb_fs = load_workbook('fs_analy.xlsx')
ws_fs = wb_fs.worksheets[0]

print(ws_fs)

# 테두리를 지정하기 위해 변수 지정
box = Border(left=Side(border_style='thin', color='FF000000'),
             right=Side(border_style='thin', color='FF000000'),
             top=Side(border_style='thin', color='FF000000'),
             bottom=Side(border_style='thin', color='FF000000'))

# 컬럼 너비를 조정
col_fs = 1
while ws_fs.cell(2, col_fs).value != None:
    ws_fs.column_dimensions[get_column_letter(col_fs)].width = 20
    col_fs += 1

    # 숫자를 천단위 구분 표시
    row_fs = 2
    while row_fs < ws_fs.max_row + 1:
        ws_fs.cell(row_fs, col_fs).number_format = '#,##0'
        ws_fs.cell(row_fs, col_fs).border = box
        row_fs += 1

    # 숫자를 백분위로 표시
    row_fp = 28
    while row_fp < ws_fs.max_row + 1:
        ws_fs.cell(row_fp, col_fs).number_format = '0.00%'
        row_fp += 1

for row in range(1, ws_fs.max_row+1):
    if ws_fs.cell(row, 2).value == 0:
        ws_fs.cell(row, 2).value = ws_fs.cell(row, 1).value

ws_fs.cell(1, 1).value = file
wb_fs.save('fs_analy_' + file)
wb_fs.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2508/310248163.py in <module>
#       7 file = 'KPX케미칼.xlsx'
#       8
# ----> 9 wb = load_workbook(file)
#      10 item_list = []
#      11
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     313
#     314     """
# --> 315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
#     317     reader.read()
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# --> 124         self.archive = _validate_archive(fn)
#     125         self.valid_files = self.archive.namelist()
#     126         self.read_only = read_only
#
# ~\anaconda3\lib\site-packages\openpyxl\reader\excel.py in _validate_archive(filename)
#      94             raise InvalidFileException(msg)
#      95
# ---> 96     archive = ZipFile(filename, 'r')
#      97     return archive
#      98
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1237             while True:
#    1238                 try:
# -> 1239                     self.fp = io.open(file, filemode)
#    1240                 except OSError:
#    1241                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'KPX케미칼.xlsx'
